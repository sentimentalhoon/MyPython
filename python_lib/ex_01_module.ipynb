# %%
# 주피명 파일명 == module, library
# 일반적으로 모듈명은 내장된 기능들을 아우르는 (포괄하는) 개념이 좋다.

# %%
import module_test as mt

mt.add(4, 5)
mt.sub(4, 5)
# Out:
# -9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](attachment:image.png)
